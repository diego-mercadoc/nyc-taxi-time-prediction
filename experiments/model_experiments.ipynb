# %%
import os
import requests

# Crear el directorio si no existe
os.makedirs('../data', exist_ok=True)

# Función para descargar archivos
def download_file(url, save_path):
    response = requests.get(url)
    with open(save_path, 'wb') as f:
        f.write(response.content)

# Descargar los archivos
download_file('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet', '../data/green_tripdata_2024-01.parquet')
download_file('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-02.parquet', '../data/green_tripdata_2024-02.parquet')

# %%
import pickle
import pandas as pd
from sklearn.metrics import  root_mean_squared_error
from sklearn.feature_extraction import  DictVectorizer
from sklearn.linear_model import Lasso, Ridge, LinearRegression

# %%
def read_dataframe(filename):

    df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)

    return df

# %%
df_train = read_dataframe('../data/green_tripdata_2024-01.parquet')
df_val = read_dataframe('../data/green_tripdata_2024-02.parquet')

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO']  #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']
dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
import dagshub
import mlflow


dagshub.init(url="https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction", mlflow=True)

MLFLOW_TRACKING_URI = mlflow.get_tracking_uri()

print(MLFLOW_TRACKING_URI)

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment(experiment_name="nyc-taxi-experiment")
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# Output()
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=ec14fab5-d0fc-46cc-a0d9-20457aa8f997&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=f992f330d64bf4efc99945cdf35d795031e03ce7e3ccccc9032b517bc09780a8
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Accessing as diego-mercadoc
# Initialized MLflow to track repo "diego-mercadoc/nyc-taxi-time-prediction"
# Repository diego-mercadoc/nyc-taxi-time-prediction initialized!
# https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow
# 2024/09/17 21:28:49 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/4a2f89adc0ff477ead9bc8f38ff1a8ba', creation_time=1726630128698, experiment_id='0', last_update_time=1726630128698, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
training_dataset = mlflow.data.from_numpy(X_train.data, targets=y_train, name="green_tripdata_2024-01")
validation_dataset = mlflow.data.from_numpy(X_val.data, targets=y_val, name="green_tripdata_2024-02")

# %%
from dagshub import get_repo_bucket_client
# Get a boto3.client object
s3 = get_repo_bucket_client("diego-mercadoc/nyc-taxi-time-prediction")

# Upload file
s3.upload_file(
    Bucket="nyc-taxi-time-prediction",  # name of the repo
    Filename="../data/green_tripdata_2024-01.parquet",  # local path of file to upload
    Key="train_data.parquet",  # remote path where to upload the file
)

# Upload file
s3.upload_file(
    Bucket="nyc-taxi-time-prediction",  # name of the repo
    Filename="../data/green_tripdata_2024-02.parquet",  # local path of file to upload
    Key="eval_data.parquet",  # remote path where to upload the file
)
# Out:
# Client created. Use the name of the repo (nyc-taxi-time-prediction) as the name of the bucket

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
import pathlib

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run(nested=True):
         
        # Tag model
        mlflow.set_tag("model_family", "xgboost")
        
        # Log parameters
        mlflow.log_params(params)
        
        # Train model
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=10
        )
        
        # Log xgboost model with artifact_path
        mlflow.xgboost.log_model(booster, artifact_path="model")
         
        # Predict in the val dataset
        y_pred = booster.predict(valid)
        
        # Calculate metric
        rmse = root_mean_squared_error(y_val, y_pred)
        
        # Log performance metric
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
mlflow.xgboost.autolog()

with mlflow.start_run(run_name="Xgboost Hyper-parameter Optimization", nested=True):
    search_space = {
        'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
        'learning_rate': hp.loguniform('learning_rate', -3, 0),
        'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
        'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
        'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
        'objective': 'reg:squarederror',
        'seed': 42
    }
    
    best_params = fmin(
        fn=objective,
        space=search_space,
        algo=tpe.suggest,
        max_evals=10,
        trials=Trials()
    )
    best_params["max_depth"] = int(best_params["max_depth"])
    best_params["seed"] = 42
    best_params["objective"] = "reg:squarederror"
    
    mlflow.log_params(best_params)

    # Log tags
    mlflow.set_tags(
        tags={
            "project": "NYC Taxi Time Prediction Project",
            "optimizer_engine": "hyper-opt",
            "model_family": "xgboost",
            "feature_set_version": 1,
        }
    )

    # Log a fit model instance
    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=100,
        evals=[(valid, 'validation')],
        early_stopping_rounds=10
    )
        
    y_pred = booster.predict(valid)
    
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)
    
    pathlib.Path("models").mkdir(exist_ok=True)
    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
        
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
# Out:
# [0]	validation-rmse:7.88285
# [1]	validation-rmse:7.02368
# [2]	validation-rmse:6.43411
# [3]	validation-rmse:6.06322
# [4]	validation-rmse:5.77666
# [5]	validation-rmse:5.62864
# [6]	validation-rmse:5.52521
# [7]	validation-rmse:5.45821
# [8]	validation-rmse:5.40409
# [9]	validation-rmse:5.38300
# [10]	validation-rmse:5.36935
# [11]	validation-rmse:5.34143
# [12]	validation-rmse:5.33238
# [13]	validation-rmse:5.32674
# [14]	validation-rmse:5.31591
# [15]	validation-rmse:5.31350
# [16]	validation-rmse:5.31148
# [17]	validation-rmse:5.31098
# [18]	validation-rmse:5.31028
# [19]	validation-rmse:5.30841
# [20]	validation-rmse:5.30513
# [21]	validation-rmse:5.30174
# [22]	validation-rmse:5.30169
# [23]	validation-rmse:5.30216
# [24]	validation-rmse:5.30144
# [25]	validation-rmse:5.30149
# [26]	validation-rmse:5.29774
# [27]	validation-rmse:5.29851
# [28]	validation-rmse:5.29896
# [29]	validation-rmse:5.29832
# [30]	validation-rmse:5.29801
# [31]	validation-rmse:5.29750
# [32]	validation-rmse:5.29727
# [33]	validation-rmse:5.29784
# [34]	validation-rmse:5.29752
# [35]	validation-rmse:5.29761
# [36]	validation-rmse:5.29600
# [37]	validation-rmse:5.29675
# [38]	validation-rmse:5.29739
# [39]	validation-rmse:5.29809
# [40]	validation-rmse:5.29814
# [41]	validation-rmse:5.29781
# [42]	validation-rmse:5.29756
# [43]	validation-rmse:5.29744
# [44]	validation-rmse:5.29722
# [45]	validation-rmse:5.29717
# [46]	validation-rmse:5.29742
#   0%|                                                                                                              | 0/10 [00:24<?, ?trial/s, best loss=?]
# 2024/09/17 21:39:57 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
#
# 2024/09/17 21:39:57 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\diego\OneDrive - ITESO\ITESO\5 semestre\Proyecto de Ciencia de datos\nyc-taxi-time-prediction\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:39:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/17 21:40:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#
# c:\Users\diego\OneDrive - ITESO\ITESO\5 semestre\Proyecto de Ciencia de datos\nyc-taxi-time-prediction\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:40:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
#
# 2024/09/17 21:40:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#
# 2024/09/17 21:40:11 INFO mlflow.tracking._tracking_service.client: 🏃 View run classy-dog-881 at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0/runs/5a65510fcd4e4bfcb27248c14bff46ed.
#
# 2024/09/17 21:40:11 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0.
# [0]	validation-rmse:6.17120
# [1]	validation-rmse:5.60789
# [2]	validation-rmse:5.50790
# [3]	validation-rmse:5.48088
# [4]	validation-rmse:5.45581
# [5]	validation-rmse:5.45020
# [6]	validation-rmse:5.44613
# [7]	validation-rmse:5.43491
# [8]	validation-rmse:5.42801
# [9]	validation-rmse:5.42337
# [10]	validation-rmse:5.42070
# [11]	validation-rmse:5.40834
# [12]	validation-rmse:5.40678
# [13]	validation-rmse:5.38340
# [14]	validation-rmse:5.38116
# [15]	validation-rmse:5.37867
# [16]	validation-rmse:5.37494
# [17]	validation-rmse:5.37391
# [18]	validation-rmse:5.36776
# [19]	validation-rmse:5.36417
# [20]	validation-rmse:5.36214
# [21]	validation-rmse:5.35953
# [22]	validation-rmse:5.35873
# [23]	validation-rmse:5.35950
# [24]	validation-rmse:5.35887
# [25]	validation-rmse:5.35744
# [26]	validation-rmse:5.35662
# [27]	validation-rmse:5.35548
# [28]	validation-rmse:5.35377
# [29]	validation-rmse:5.35009
# [30]	validation-rmse:5.34663
# [31]	validation-rmse:5.34389
# [32]	validation-rmse:5.34192
# [33]	validation-rmse:5.34027
# [34]	validation-rmse:5.33953
# [35]	validation-rmse:5.33663
# [36]	validation-rmse:5.33633
# [37]	validation-rmse:5.33555
# [38]	validation-rmse:5.33527
# [39]	validation-rmse:5.33269
# [40]	validation-rmse:5.33266
# [41]	validation-rmse:5.33098
# [42]	validation-rmse:5.32743
# [43]	validation-rmse:5.32543
# [44]	validation-rmse:5.32371
# [45]	validation-rmse:5.32123
# [46]	validation-rmse:5.31959
# [47]	validation-rmse:5.32005
# [48]	validation-rmse:5.31904
# [49]	validation-rmse:5.31835
# [50]	validation-rmse:5.31735
# [51]	validation-rmse:5.31585
# [52]	validation-rmse:5.31596
# [53]	validation-rmse:5.31462
# [54]	validation-rmse:5.31543
# [55]	validation-rmse:5.31566
# [56]	validation-rmse:5.31368
# [57]	validation-rmse:5.31360
# [58]	validation-rmse:5.31319
# [59]	validation-rmse:5.31278
# [60]	validation-rmse:5.31282
# [61]	validation-rmse:5.31189
# [62]	validation-rmse:5.31111
# [63]	validation-rmse:5.31046
# [64]	validation-rmse:5.30988
# [65]	validation-rmse:5.30975
# [66]	validation-rmse:5.30979
# [67]	validation-rmse:5.30901
# [68]	validation-rmse:5.30758
# [69]	validation-rmse:5.30607
# [70]	validation-rmse:5.30523
# [71]	validation-rmse:5.30473
# [72]	validation-rmse:5.30387
# [73]	validation-rmse:5.30316
# [74]	validation-rmse:5.30246
# [75]	validation-rmse:5.30267
# [76]	validation-rmse:5.30264
# [77]	validation-rmse:5.30059
# [78]	validation-rmse:5.30039
# [79]	validation-rmse:5.29981
# [80]	validation-rmse:5.30018
# [81]	validation-rmse:5.29998
# [82]	validation-rmse:5.29943
# [83]	validation-rmse:5.29897
# [84]	validation-rmse:5.29776
# [85]	validation-rmse:5.29740
# [86]	validation-rmse:5.29665
# [87]	validation-rmse:5.29657
# [88]	validation-rmse:5.29524
# [89]	validation-rmse:5.29431
# [90]	validation-rmse:5.29365
# [91]	validation-rmse:5.29175
# [92]	validation-rmse:5.29214
# [93]	validation-rmse:5.29211
# [94]	validation-rmse:5.29164
# [95]	validation-rmse:5.29140
# [96]	validation-rmse:5.29127
# [97]	validation-rmse:5.29086
# [98]	validation-rmse:5.29067
# [99]	validation-rmse:5.28988
#  10%|████████▌                                                                            | 1/10 [00:57<08:08, 54.26s/trial, best loss: 5.297423310048957]
# 2024/09/17 21:40:17 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
#
# 2024/09/17 21:40:17 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\diego\OneDrive - ITESO\ITESO\5 semestre\Proyecto de Ciencia de datos\nyc-taxi-time-prediction\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:40:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/17 21:40:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#
# c:\Users\diego\OneDrive - ITESO\ITESO\5 semestre\Proyecto de Ciencia de datos\nyc-taxi-time-prediction\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:40:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
#
# 2024/09/17 21:40:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#
# 2024/09/17 21:40:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run gaudy-dove-381 at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0/runs/22dabeb0ad5b47bcbe8a86c76c8e4996.
#
# 2024/09/17 21:40:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0.
# [0]	validation-rmse:6.70352
# [1]	validation-rmse:5.84604
# [2]	validation-rmse:5.58006
# [3]	validation-rmse:5.48988
# [4]	validation-rmse:5.45316
# [5]	validation-rmse:5.43521
# [6]	validation-rmse:5.42484
# [7]	validation-rmse:5.42121
# [8]	validation-rmse:5.41633
# [9]	validation-rmse:5.41029
# [10]	validation-rmse:5.40634
# [11]	validation-rmse:5.40119
# [12]	validation-rmse:5.39813
# [13]	validation-rmse:5.39481
# [14]	validation-rmse:5.39220
# [15]	validation-rmse:5.38633
# [16]	validation-rmse:5.38307
# [17]	validation-rmse:5.38118
# [18]	validation-rmse:5.37674
# [19]	validation-rmse:5.37521
# [20]	validation-rmse:5.37318
# [21]	validation-rmse:5.36387
# [22]	validation-rmse:5.36091
# [23]	validation-rmse:5.35976
# [24]	validation-rmse:5.35874
# [25]	validation-rmse:5.35616
# [26]	validation-rmse:5.35387
# [27]	validation-rmse:5.35223
# [28]	validation-rmse:5.35161
# [29]	validation-rmse:5.35255
# [30]	validation-rmse:5.35156
# [31]	validation-rmse:5.34404
# [32]	validation-rmse:5.33992
# [33]	validation-rmse:5.33850
# [34]	validation-rmse:5.33755
# [35]	validation-rmse:5.33542
# [36]	validation-rmse:5.33379
# [37]	validation-rmse:5.33337
# [38]	validation-rmse:5.33202
# [39]	validation-rmse:5.33219
# [40]	validation-rmse:5.33111
# [41]	validation-rmse:5.33011
# [42]	validation-rmse:5.32916
# [43]	validation-rmse:5.32824
# [44]	validation-rmse:5.32703
# [45]	validation-rmse:5.32616
# [46]	validation-rmse:5.32581
# [47]	validation-rmse:5.32536
# [48]	validation-rmse:5.32441
# [49]	validation-rmse:5.32401
# [50]	validation-rmse:5.32346
# [51]	validation-rmse:5.32238
# [52]	validation-rmse:5.32174
# [53]	validation-rmse:5.32165
# [54]	validation-rmse:5.32098
# [55]	validation-rmse:5.32090
# [56]	validation-rmse:5.32042
# [57]	validation-rmse:5.31933
# [58]	validation-rmse:5.31877
# [59]	validation-rmse:5.31685
# [60]	validation-rmse:5.31516
# [61]	validation-rmse:5.31498
# [62]	validation-rmse:5.31473
# [63]	validation-rmse:5.31394
# [64]	validation-rmse:5.31357
# [65]	validation-rmse:5.31310
# [66]	validation-rmse:5.31238
# [67]	validation-rmse:5.31206
# [68]	validation-rmse:5.31009
# [69]	validation-rmse:5.30902
# [70]	validation-rmse:5.30841
# [71]	validation-rmse:5.30815
# [72]	validation-rmse:5.30696
# [73]	validation-rmse:5.30602
# [74]	validation-rmse:5.30631
# [75]	validation-rmse:5.30537
# [76]	validation-rmse:5.30455
# [77]	validation-rmse:5.30433
# [78]	validation-rmse:5.30414
# [79]	validation-rmse:5.30368
# [80]	validation-rmse:5.30284
# [81]	validation-rmse:5.30290
# [82]	validation-rmse:5.30064
# [83]	validation-rmse:5.30071
# [84]	validation-rmse:5.29951
# [85]	validation-rmse:5.29901
# [86]	validation-rmse:5.29830
# [87]	validation-rmse:5.29874
# [88]	validation-rmse:5.29758
# [89]	validation-rmse:5.29763
# [90]	validation-rmse:5.29629
# [91]	validation-rmse:5.29563
# [92]	validation-rmse:5.29579
# [93]	validation-rmse:5.29550
# [94]	validation-rmse:5.29532
# [95]	validation-rmse:5.29501
# [96]	validation-rmse:5.29406
# [97]	validation-rmse:5.29406
# [98]	validation-rmse:5.29397
# [99]	validation-rmse:5.29394
#  20%|█████████████████                                                                    | 2/10 [01:13<04:16, 32.08s/trial, best loss: 5.289882614739589]
# 2024/09/17 21:40:33 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
#
# 2024/09/17 21:40:33 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\diego\OneDrive - ITESO\ITESO\5 semestre\Proyecto de Ciencia de datos\nyc-taxi-time-prediction\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:40:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/17 21:40:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#
# c:\Users\diego\OneDrive - ITESO\ITESO\5 semestre\Proyecto de Ciencia de datos\nyc-taxi-time-prediction\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:40:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
#
# 2024/09/17 21:40:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#
# 2024/09/17 21:40:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run victorious-eel-180 at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0/runs/babe8125df5747659ea34830ee361b82.
#
# 2024/09/17 21:40:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0.
# [0]	validation-rmse:6.90361
# [1]	validation-rmse:6.03902
# [2]	validation-rmse:5.72013
# [3]	validation-rmse:5.59562
# [4]	validation-rmse:5.53288
# [5]	validation-rmse:5.51099
# [6]	validation-rmse:5.49920
# [7]	validation-rmse:5.49425
# [8]	validation-rmse:5.48809
# [9]	validation-rmse:5.48120
# [10]	validation-rmse:5.47830
# [11]	validation-rmse:5.47426
# [12]	validation-rmse:5.46902
# [13]	validation-rmse:5.46258
# [14]	validation-rmse:5.45976
# [15]	validation-rmse:5.45674
# [16]	validation-rmse:5.45022
# [17]	validation-rmse:5.44112
# [18]	validation-rmse:5.43811
# [19]	validation-rmse:5.43709
# ...
# [40]	validation-rmse:5.31659
# [41]	validation-rmse:5.31494
# [42]	validation-rmse:5.31344
# [43]	validation-rmse:5.31271
# [44]	validation-rmse:5.31222
# [45]	validation-rmse:5.31122
# [46]	validation-rmse:5.31082
# [47]	validation-rmse:5.31031
# [48]	validation-rmse:5.31100
# [49]	validation-rmse:5.30952
# [50]	validation-rmse:5.30980
# [51]	validation-rmse:5.30883
# [52]	validation-rmse:5.30712
# [53]	validation-rmse:5.30606
# [54]	validation-rmse:5.30566
# [55]	validation-rmse:5.30306
# [56]	validation-rmse:5.30277
# [57]	validation-rmse:5.30295
# [58]	validation-rmse:5.30262
# [59]	validation-rmse:5.30205
# [60]	validation-rmse:5.30137
# [61]	validation-rmse:5.30158
# [62]	validation-rmse:5.30012
# [63]	validation-rmse:5.29997
# [64]	validation-rmse:5.29916
# [65]	validation-rmse:5.29937
# [66]	validation-rmse:5.29922
# [67]	validation-rmse:5.29816
# [68]	validation-rmse:5.29791
# [69]	validation-rmse:5.29775
# [70]	validation-rmse:5.29844
# [71]	validation-rmse:5.29670
# [72]	validation-rmse:5.29741
# [73]	validation-rmse:5.29685
# [74]	validation-rmse:5.29655
# [75]	validation-rmse:5.29671
# [76]	validation-rmse:5.29694
# [77]	validation-rmse:5.29714
# [78]	validation-rmse:5.29677
# [79]	validation-rmse:5.29690
# [80]	validation-rmse:5.29720
# [81]	validation-rmse:5.29645
# [82]	validation-rmse:5.29634
# [83]	validation-rmse:5.29620
# [84]	validation-rmse:5.29542
# [85]	validation-rmse:5.29417
# [86]	validation-rmse:5.29307
# [87]	validation-rmse:5.29248
# [88]	validation-rmse:5.29168
# [89]	validation-rmse:5.29101
# [90]	validation-rmse:5.29093
# [91]	validation-rmse:5.29065
# [92]	validation-rmse:5.28826
# [93]	validation-rmse:5.28733
# [94]	validation-rmse:5.28749
# [95]	validation-rmse:5.28746
# [96]	validation-rmse:5.28678
# [97]	validation-rmse:5.28700
# [98]	validation-rmse:5.28633
# [99]	validation-rmse:5.28636
#  90%|████████████████████████████████████████████████████████████████████████████▌        | 9/10 [03:50<00:23, 23.40s/trial, best loss: 5.160976224940984]
# 2024/09/17 21:43:10 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
#
# 2024/09/17 21:43:10 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\diego\OneDrive - ITESO\ITESO\5 semestre\Proyecto de Ciencia de datos\nyc-taxi-time-prediction\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:43:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/17 21:43:13 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#
# c:\Users\diego\OneDrive - ITESO\ITESO\5 semestre\Proyecto de Ciencia de datos\nyc-taxi-time-prediction\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:43:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
#
# 2024/09/17 21:43:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#
# 2024/09/17 21:43:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run lyrical-slug-919 at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0/runs/015fa78c13244c61b1679f0febb94ac8.
#
# 2024/09/17 21:43:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0.
# 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [04:04<00:00, 24.41s/trial, best loss: 5.160976224940984]
# [0]	validation-rmse:7.99622
# [1]	validation-rmse:7.17716
# [2]	validation-rmse:6.58565
# [3]	validation-rmse:6.16765
# [4]	validation-rmse:5.87458
# [5]	validation-rmse:5.67329
# [6]	validation-rmse:5.53747
# [7]	validation-rmse:5.43895
# [8]	validation-rmse:5.37163
# [9]	validation-rmse:5.32768
# [10]	validation-rmse:5.28922
# [11]	validation-rmse:5.26246
# [12]	validation-rmse:5.24231
# [13]	validation-rmse:5.22682
# [14]	validation-rmse:5.21526
# [15]	validation-rmse:5.20712
# [16]	validation-rmse:5.19982
# [17]	validation-rmse:5.19415
# [18]	validation-rmse:5.19060
# [19]	validation-rmse:5.18758
# [20]	validation-rmse:5.18474
# [21]	validation-rmse:5.18422
# [22]	validation-rmse:5.18433
# [23]	validation-rmse:5.18209
# [24]	validation-rmse:5.18217
# [25]	validation-rmse:5.18087
# [26]	validation-rmse:5.18117
# [27]	validation-rmse:5.18023
# [28]	validation-rmse:5.18044
# [29]	validation-rmse:5.17954
# [30]	validation-rmse:5.17926
# [31]	validation-rmse:5.17809
# [32]	validation-rmse:5.17729
# [33]	validation-rmse:5.17757
# [34]	validation-rmse:5.17831
# [35]	validation-rmse:5.17784
# [36]	validation-rmse:5.17667
# [37]	validation-rmse:5.17625
# [38]	validation-rmse:5.17577
# [39]	validation-rmse:5.17532
# [40]	validation-rmse:5.17475
# [41]	validation-rmse:5.17433
# [42]	validation-rmse:5.17367
# [43]	validation-rmse:5.17276
# [44]	validation-rmse:5.17259
# [45]	validation-rmse:5.17221
# [46]	validation-rmse:5.17075
# [47]	validation-rmse:5.17057
# [48]	validation-rmse:5.16947
# [49]	validation-rmse:5.16977
# [50]	validation-rmse:5.16962
# [51]	validation-rmse:5.16969
# [52]	validation-rmse:5.16877
# [53]	validation-rmse:5.16861
# [54]	validation-rmse:5.16841
# [55]	validation-rmse:5.16864
# [56]	validation-rmse:5.16832
# [57]	validation-rmse:5.16807
# [58]	validation-rmse:5.16806
# [59]	validation-rmse:5.16730
# [60]	validation-rmse:5.16726
# [61]	validation-rmse:5.16681
# [62]	validation-rmse:5.16697
# [63]	validation-rmse:5.16673
# [64]	validation-rmse:5.16650
# [65]	validation-rmse:5.16519
# [66]	validation-rmse:5.16551
# [67]	validation-rmse:5.16495
# [68]	validation-rmse:5.16466
# [69]	validation-rmse:5.16471
# [70]	validation-rmse:5.16442
# [71]	validation-rmse:5.16355
# [72]	validation-rmse:5.16386
# [73]	validation-rmse:5.16314
# [74]	validation-rmse:5.16319
# [75]	validation-rmse:5.16347
# [76]	validation-rmse:5.16292
# [77]	validation-rmse:5.16321
# [78]	validation-rmse:5.16294
# [79]	validation-rmse:5.16265
# [80]	validation-rmse:5.16253
# [81]	validation-rmse:5.16273
# [82]	validation-rmse:5.16248
# [83]	validation-rmse:5.16206
# [84]	validation-rmse:5.16248
# [85]	validation-rmse:5.16244
# [86]	validation-rmse:5.16206
# [87]	validation-rmse:5.16231
# [88]	validation-rmse:5.16145
# [89]	validation-rmse:5.16065
# [90]	validation-rmse:5.16093
# [91]	validation-rmse:5.16130
# [92]	validation-rmse:5.16152
# [93]	validation-rmse:5.16151
# [94]	validation-rmse:5.16101
# [95]	validation-rmse:5.16143
# [96]	validation-rmse:5.16137
# [97]	validation-rmse:5.16172
# [98]	validation-rmse:5.16160
# 2024/09/17 21:43:49 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/09/17 21:43:49 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\diego\OneDrive - ITESO\ITESO\5 semestre\Proyecto de Ciencia de datos\nyc-taxi-time-prediction\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:43:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2024/09/17 21:43:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 21:43:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run Xgboost Hyper-parameter Optimization at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0/runs/e2e66d7be851466da7f92b56e1add8f1.
# 2024/09/17 21:43:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/diego-mercadoc/nyc-taxi-time-prediction.mlflow/#/experiments/0.

# %%
run_id = input("Ingrese el run_id")
run_uri = f"runs:/{run_id}/model"

result = mlflow.register_model(
    model_uri=run_uri,
    name="nyc-taxi-model"
)
# Out:
# Ingrese el run_id debee74804e849efa17146dba3483920
# Successfully registered model 'nyc-taxi-model'.
# 2024/09/17 21:50:48 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: nyc-taxi-model, version 1
# Created version '1' of model 'nyc-taxi-model'.

# %%
from datetime import datetime
from mlflow import MlflowClient

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)
client.update_registered_model(
    name="nyc-taxi-model",
    description="Model registry for the NYC Taxi Time Prediction Project",
)

new_alias = "champion"
date = datetime.today()
model_version = "1"

# create "champion" alias for version 1 of model "nyc-taxi-model"
client.set_registered_model_alias(
    name="nyc-taxi-model",
    alias=new_alias,
    version=model_version
)

client.update_model_version(
    name="nyc-taxi-model",
    version=model_version,
    description=f"The model version {model_version} was transitioned to {new_alias} on {date}",
)
# Out:
# <ModelVersion: aliases=['champion'], creation_timestamp=1726631447429, current_stage='None', description='The model version 1 was transitioned to champion on 2024-09-17 21:51:16.881680', last_updated_timestamp=1726631476589, name='nyc-taxi-model', run_id='debee74804e849efa17146dba3483920', run_link='', source='mlflow-artifacts:/4a2f89adc0ff477ead9bc8f38ff1a8ba/debee74804e849efa17146dba3483920/artifacts/model', status='READY', status_message='', tags={}, user_id='', version='1'>

# %%
import mlflow.pyfunc

model_name = "nyc-taxi-model"
alias = "champion"

model_uri = f"models:/{model_name}@{alias}"

champion_version = mlflow.pyfunc.load_model(
    model_uri=model_uri
)

champion_version.predict(X_val)
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# array([19.053276, 28.44469 ,  9.331161, ..., 45.867966, 13.883814,
#        19.686247], dtype=float32)
